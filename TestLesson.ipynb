# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidSenseman/BIO1173/blob/main/TestLesson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---------------------------
# **COPYRIGHT NOTICE:** This Jupyterlab Notebook is a Derivative work of [Jeff Heaton](https://github.com/jeffheaton) licensed under the Apache License, Version 2.0 (the "License"); You may not use this file except in compliance with the License. You may obtain a copy of the License at
#
# > [http://www.apache.org/licenses/LICENSE-2.0](http://www.apache.org/licenses/LICENSE-2.0)
#
# Unless required by applicable law or agreed to in writing, software distributed under the License is distributed on an "AS IS" BASIS, WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied. See the License for the specific language governing permissions and limitations under the License.
#
# ------------------------

# %% [markdown]
# # **BIO 1173: Intro Computational Biology**

# %% [markdown]
# ##### **Module 3: Convolutional Neural Networks (CNN's)**
#
# * Instructor: [David Senseman](mailto:David.Senseman@utsa.edu), [Department of Biology, Health and the Environment](https://sciences.utsa.edu/bhe/), [UTSA](https://www.utsa.edu/)
#
# ### Module 3 Material
#
# * **Part 3.1: Using Convolutional Neural Networks**
# * Part 3.2: Using Pre-Trained Neural Networks with Pytorch
# * Part 3.3: Facial Recognition and Analysis
# * Part 3.4: Introduction to GAN's for Image and Data Generation

# %%
# You must run this cell first
try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    from google.colab import auth
    auth.authenticate_user()
    COLAB = True
    print("Note: Using Google CoLab")
    import requests
    gcloud_token = !gcloud auth print-access-token
    gcloud_tokeninfo = requests.get('https://www.googleapis.com/oauth2/v3/tokeninfo?access_token=' + gcloud_token[0]).json()
    print(gcloud_tokeninfo['email'])
except:
    print("**WARNING**: Your GMAIL address was **not** printed in the output below.")
    print("**WARNING**: You will NOT receive credit for this lesson.")
    COLAB = False

# %% [markdown]
# You should see the following output except your GMAIL address should appear on the last line.
#
# ![__](https://biologicslab.co/BIO1173/images/class_01/class_01_6_image01A.png)
#
# If your GMAIL address does not appear your lesson will **not** be graded.

# %% [markdown]
# ### Test Your BIO1173_API_KEY
#
# In order to run the code in this lesson you will need to have your secret `BIO1173_API_KEY` installed in your **Secrets** on this Colab notebook. If you are a registered student in BIO1173 during the current system, you were emailed you `BIO1173_API_KEY`. If you are having trouble, ask your Instructor and/or the TA for help, that is what they are here for.
#
# Run the code in the next cell to see if your `GEMINI_API_KEY` is installed correctly. You make have to Grant Access for your notebook to use your API key.

# %%
# Verify your API key setup

from google.colab import userdata
import os

# Check if API key is properly loaded
try:
    BIO1173_API_KEY = userdata.get('BIO1173_API_KEY')
    print("API key loaded successfully!")
    print(f"Key length: {len(BIO1173_API_KEY)}")
except Exception as e:
    print(f"Error loading API key: {e}")
    print("Please set-up your BIO1173_API_KEY key in your Colab Secrets")
# Out:
# Error loading API key: Secret BIO1173_API_KEY does not exist.
# Please set-up your BIO1173_API_KEY key in your Colab Secrets

# %% [markdown]
# ### Example 1: Run Cell
#
# Run the code in the next cell.

# %%
# Example 1

str="Hello David"

print(st)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-293194166.py in <cell line: 0>()
#       3 str="Hello David"
#       4
# ----> 5 print(st)
#
# NameError: name 'st' is not defined

# %% [markdown]
# ### **Exercise 1**
#
# Run the next cell.

# %%
# Insert your code for Exercise 1
str="Hello David"

print(str)
# Out:
# Hello David

# %% [markdown]
# ### **Lesson Turn In**
#
# When you run the next and last code cell your Colab notebook will be automatically sent for grading. Please watch the output to see if you lesson was sent sucessfully or are there errors that need to be resolved before you can submit.

# %%
# BIO1173 Lesson Submission Cell
# Run this cell to submit your lesson for grading
import json
import requests
from google.colab import userdata

# Configuration
WEBHOOK_URL = "https://your-openclaw-gateway/hooks/submit"  # We'll set this up
LESSON_ID = "TestLesson"

def submit_lesson():
     """Extract and submit lesson data for grading"""

    # Get student credentials
     try:
         api_key = userdata.get('BIO1173_API_KEY')
     except Exception as e:
         print("❌ ERROR: BIO1173_API_KEY not found in Colab Secrets")
         print("   Please add your API key to Secrets before submitting")
         return

     # Get student email from earlier cell output
     # Note: We'll need to capture this properly
     try:
         # Re-authenticate to get email
         import requests
         gcloud_token = !gcloud auth print-access-token
         token_info = requests.get(
             'https://www.googleapis.com/oauth2/v3/tokeninfo?access_token=' + gcloud_token[0]
         ).json()
         student_email = token_info['email']
     except:
         print("❌ ERROR: Could not verify your Gmail address")
         print("   Please run the first cell again")
         return

     # Extract exercise code
     # In the real implementation, we'd parse the notebook JSON
     # For now, we'll collect what we can from the runtime

     submission_data = {
         "lesson_id": LESSON_ID,
         "student_email": student_email,
         "api_key": api_key,
         "timestamp": str(datetime.now()),
         # We'd include exercise outputs, execution counts, etc.
     }

     print(f"📧 Student: {student_email}")
     print(f"🔑 API Key: {api_key[:8]}... (verified)")
     print(f"📋 Lesson: {LESSON_ID}")
     print("\n🚀 Submitting...")

     # POST to webhook
     try:
         response = requests.post(
             WEBHOOK_URL,
             json=submission_data,
             headers={"Content-Type": "application/json"},
             timeout=30
         )
         if response.status_code == 200:
             print("✅ Submission successful!")
             print(f"   Response: {response.json()}")
         else:
             print(f"❌ Submission failed: {response.status_code}")
             print(f"   {response.text}")
     except Exception as e:
         print(f"❌ Network error: {e}")

# Run submission
from datetime import datetime
submit_lesson()
# Out:
# ❌ ERROR: BIO1173_API_KEY not found in Colab Secrets
#    Please add your API key to Secrets before submitting
